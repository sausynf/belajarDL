# %% [markdown]
# # Pertemuan 5 (Convolutional Neural Network)
#
# ### Mata Kuliah Pembelajaran Mendalam

# %% [markdown]
# ## Convolusi

# %% [markdown]
# ![Untitled Diagram-Page-6.drawio.png](data:image/png;base64,...)

# %% [markdown]
# # Stride

# %% [markdown]
# ![Untitled Diagram-Page-7.drawio.png](data:image/png;base64,...)

# %% [markdown]
# # Padding

# %% [markdown]
# ![Untitled Diagram-Page-9.drawio.png](data:image/png;base64,...)

# %% [markdown]
# # Pooling

# %% [markdown]
# ![Untitled Diagram-Page-8.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## Latihan Membuat Model

# %% [markdown]
# ### 1 - Import Library

# %%
# Import Library yang digunakan
import matplotlib.pyplot as plt
import cv2
import numpy as np
from keras import layers, models
from keras.datasets import mist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Import Library yang digunakan
#       2 import matplotlib.pyplot as plt
# ----> 3 import cv2
#       4 import numpy as np
#       5 from keras import layers, models
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ### 2 - Read and Split Dataset

# %% [markdown]
# Menggunakan dataset "MNIST" yang tersedia.
#
# MNIST dataset adalah data besar berisi angka-angka tulisan tangan yang biasa digunakan untuk melatih berbagai sistem pemrosesan gambar.
#
# Link dataset kaggle: https://www.kaggle.com/datasets/hojjatk/mnist-dataset

# %%
# Load dataset and split data train and test

# %%
# Read data

# %% [markdown]
# ### 3 - Preprocessing

# %%
# Reshipe and Normalize data

# %% [markdown]
# > x_train dan x_test direshape dengan ukuran 60000 data, ukuran 28x28 dan warna grayscale.
#
# > x_train dan x_test dilakukan normalisasi.

# %%
# Check Class Data

# %% [markdown]
# Terlihat bahwa terdapat 10 kelas dataset yaitu angka 0 - 9.

# %% [markdown]
# ### 4 - Pemodelan Menggunakan CNN

# %%
# Create CNN Architecture

# %%
# Summary Data

# %% [markdown]
# ### 5 - Compile Model

# %%
# Compile Model

# %% [markdown]
# ### 6 - Training Model

# %%
# Training Model

# %%
# Evaluate using Matplotlib

# %% [markdown]
# ### 7 - Evaluasi Model

# %%
# Test Accuracy model

# %% [markdown]
# ### 8 - Prediksi

# %%
# Upload test image
